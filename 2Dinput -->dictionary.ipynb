# %%
def izip(*iterables):
    # izip('ABCD', 'xy') --> Ax By
    iterables = map(iter, iterables)
    while iterables:
        yield tuple(map(next, iterables))
import numpy as np
male=[1,2,3,4]
female=[1,2,3,4]
m_prefs=[[1,2,3,4],[3,2,1,4],[1,2,4,3],[3,1,4,2]]
f_prefs=np.array([[1,2,3,4],[2,1,4,3],[2,3,1,4],[1,4,3,2]])
males=dict(izip(male,m_prefs))
males
# Out:
# {1: [1, 2, 3, 4], 2: [3, 2, 1, 4], 3: [1, 2, 4, 3], 4: [3, 1, 4, 2]}

# %%
import random
male=range(59)
female=range(30)
female_choice=range(60)
f_prefs=[random.sample(female_choice,60) for i in female]
females=dict(izip(female,f_prefs))
females
# Out:
# {0: [36,
#   51,
#   16,
#   34,
#   27,
#   3,
#   14,
#   7,
#   6,
#   2,
#   22,
#   37,
#   20,
#   12,
#   23,
#   39,
#   54,
#   17,
#   41,
#   8,
#   58,
#   15,
#   21,
#   13,
#   53,
#   19,
#   26,
#   57,
#   47,
#   10,
#   9,
#   24,
#   32,
#   31,
#   33,
#   25,
#   46,
#   1,
#   50,
#   40,
#   52,
#   38,
#   55,
#   49,
#   11,
#   18,
#   44,
#   5,
#   42,
#   48,
#   59,
#   30,
#   35,
#   0,
#   56,
#   43,
#   29,
#   4,
#   45,
#   28],
#  1: [21,
#   6,
#   52,
#   28,
#   19,
#   37,
#   7,
#   11,
#   10,
#   17,
#   0,
#   2,
#   14,
#   47,
#   44,
#   4,
#   5,
#   12,
#   29,
#   59,
#   53,
#   56,
#   46,
#   39,
#   40,
#   27,
#   32,
#   36,
#   3,
#   9,
#   13,
#   38,
#   26,
#   23,
#   43,
#   15,
#   41,
#   48,
#   33,
#   24,
#   58,
#   8,
#   30,
#   34,
#   25,
#   42,
#   20,
#   31,
#   50,
#   45,
#   55,
#   18,
#   54,
#   1,
#   57,
#   49,
#   16,
#   22,
#   35,
#   51],
#  2: [23,
#   34,
#   11,
#   18,
#   56,
#   6,
#   53,
#   51,
#   50,
#   2,
#   49,
#   12,
#   28,
#   54,
#   16,
#   46,
#   41,
#   45,
#   26,
#   8,
#   25,
#   36,
#   27,
#   0,
#   31,
#   39,
#   47,
#   42,
#   10,
#   9,
#   20,
#   57,
#   22,
#   3,
#   14,
#   40,
#   4,
#   59,
#   15,
#   13,
#   37,
#   38,
#   1,
#   52,
#   21,
#   5,
#   32,
#   35,
#   30,
#   33,
#   7,
#   19,
#   48,
#   29,
#   44,
#   55,
#   43,
#   24,
#   17,
#   58],
#  3: [14,
#   35,
#   29,
#   43,
#   3,
#   28,
#   56,
#   20,
#   44,
#   33,
#   37,
#   53,
#   9,
#   54,
#   34,
#   26,
#   0,
#   2,
#   48,
#   25,
#   24,
#   42,
#   36,
#   7,
#   50,
#   21,
#   31,
#   5,
#   22,
#   39,
#   51,
#   38,
#   41,
#   58,
#   46,
#   1,
#   57,
#   55,
#   23,
#   16,
#   19,
#   59,
#   6,
#   49,
#   40,
#   30,
#   27,
#   4,
#   45,
#   8,
#   52,
#   18,
#   12,
#   10,
#   32,
#   47,
#   11,
#   15,
#   17,
#   13],
#  4: [44,
#   55,
#   16,
#   18,
#   48,
#   34,
#   25,
#   3,
#   46,
#   2,
#   53,
#   11,
#   49,
#   54,
#   17,
#   58,
#   39,
#   23,
#   33,
#   19,
#   31,
#   37,
#   13,
#   51,
#   14,
#   1,
#   12,
#   22,
#   5,
#   56,
#   35,
#   24,
#   38,
#   10,
#   42,
#   29,
#   43,
#   59,
#   6,
#   45,
#   15,
#   47,
#   36,
#   28,
#   27,
#   9,
#   30,
#   21,
#   0,
#   7,
#   4,
#   40,
#   57,
#   52,
#   41,
#   26,
#   32,
#   8,
#   50,
#   20],
#  5: [25,
#   17,
#   5,
#   49,
#   56,
#   40,
#   53,
#   28,
#   39,
#   42,
#   4,
#   52,
#   22,
#   32,
#   29,
#   8,
#   47,
#   51,
#   19,
#   26,
#   59,
#   27,
#   37,
#   20,
#   43,
#   11,
#   33,
#   50,
#   57,
#   14,
#   55,
#   58,
#   12,
#   36,
#   6,
#   31,
#   16,
#   1,
#   48,
#   21,
#   9,
#   13,
#   44,
#   30,
#   34,
#   35,
#   54,
#   15,
#   0,
#   41,
#   3,
#   2,
#   46,
#   24,
#   10,
#   38,
#   45,
#   18,
#   7,
#   23],
#  6: [21,
#   56,
#   58,
#   39,
#   34,
#   45,
#   32,
#   55,
#   50,
#   2,
#   15,
#   48,
#   51,
#   41,
#   24,
#   20,
#   31,
#   8,
#   57,
#   11,
#   49,
#   52,
#   17,
#   14,
#   1,
#   4,
#   29,
#   23,
#   16,
#   25,
#   37,
#   26,
#   12,
#   43,
#   22,
#   54,
#   27,
#   7,
#   13,
#   53,
#   33,
#   30,
#   6,
#   5,
#   36,
#   42,
#   35,
#   47,
#   46,
#   0,
#   19,
#   38,
#   40,
#   59,
#   28,
#   3,
#   10,
#   18,
#   9,
#   44],
#  7: [47,
#   20,
#   30,
#   40,
#   38,
#   6,
#   21,
#   58,
#   16,
#   55,
#   44,
#   57,
#   9,
#   13,
#   46,
#   51,
#   27,
#   5,
#   29,
#   41,
#   22,
#   34,
#   8,
#   12,
#   28,
#   42,
#   11,
#   35,
#   23,
#   43,
#   17,
#   15,
#   32,
#   56,
#   0,
#   33,
#   19,
#   59,
#   39,
#   24,
#   52,
#   50,
#   26,
#   45,
#   10,
#   2,
#   48,
#   37,
#   18,
#   3,
#   14,
#   36,
#   1,
#   25,
#   31,
#   53,
#   7,
#   49,
#   54,
#   4],
#  8: [19,
#   29,
#   45,
#   0,
#   30,
#   44,
#   20,
#   15,
#   13,
#   31,
#   46,
#   22,
#   57,
#   11,
#   34,
#   59,
#   32,
#   41,
#   48,
#   26,
#   54,
#   52,
#   43,
#   47,
#   7,
#   53,
#   38,
#   58,
#   27,
#   3,
#   16,
#   56,
#   5,
#   51,
#   24,
#   6,
#   49,
#   8,
#   28,
#   18,
#   33,
#   10,
#   36,
#   50,
#   25,
#   14,
#   39,
#   9,
#   1,
#   42,
#   37,
#   23,
#   12,
#   21,
#   55,
#   17,
#   4,
#   2,
#   35,
#   40],
#  9: [52,
#   6,
#   57,
#   42,
#   38,
#   14,
#   17,
#   34,
#   51,
#   9,
#   36,
#   41,
#   3,
#   54,
#   53,
#   11,
#   13,
#   26,
#   0,
#   1,
#   21,
#   31,
#   30,
#   2,
#   45,
#   15,
#   5,
#   58,
#   18,
#   7,
#   29,
#   39,
#   19,
#   27,
#   55,
#   50,
#   48,
#   40,
#   20,
#   46,
#   43,
#   59,
#   37,
#   28,
#   33,
#   24,
#   25,
#   10,
#   47,
#   4,
#   32,
#   56,
#   23,
#   12,
#   8,
#   49,
#   35,
#   44,
#   22,
#   16],
#  10: [2,
#   11,
#   47,
#   39,
#   36,
#   59,
#   46,
#   5,
#   24,
#   27,
#   19,
#   35,
#   57,
#   40,
#   54,
#   26,
#   3,
#   9,
#   43,
#   34,
#   20,
#   29,
#   23,
#   32,
#   7,
#   44,
#   56,
#   12,
#   38,
#   28,
#   13,
#   53,
#   1,
#   42,
#   8,
#   52,
#   25,
#   10,
#   17,
#   30,
#   33,
#   21,
#   22,
#   45,
#   49,
#   18,
#   16,
#   55,
#   15,
#   58,
#   41,
#   6,
#   51,
#   4,
#   0,
#   48,
#   31,
#   37,
#   14,
#   50],
#  11: [45,
#   7,
#   23,
#   42,
#   51,
#   56,
#   5,
#   55,
#   29,
#   33,
#   44,
#   46,
#   40,
#   3,
#   37,
#   38,
#   24,
#   6,
#   22,
#   15,
#   14,
#   25,
#   47,
#   58,
#   54,
#   31,
#   48,
#   59,
#   8,
#   9,
#   13,
#   16,
#   34,
#   52,
#   28,
#   32,
#   53,
#   12,
#   39,
#   27,
#   26,
#   30,
#   10,
#   43,
#   49,
#   18,
#   50,
#   41,
#   0,
#   35,
#   19,
#   2,
#   4,
#   11,
#   36,
#   57,
#   20,
#   17,
#   1,
#   21],
#  12: [8,
#   26,
#   51,
#   35,
#   21,
#   4,
#   59,
#   6,
#   17,
#   34,
#   3,
#   56,
#   37,
#   20,
#   43,
#   44,
#   36,
#   18,
#   7,
#   50,
#   11,
#   13,
#   49,
#   16,
#   9,
#   58,
#   53,
#   39,
#   46,
#   48,
#   2,
#   12,
#   0,
#   10,
#   15,
#   23,
#   57,
#   14,
#   29,
#   54,
#   45,
#   27,
#   19,
#   41,
#   24,
#   32,
#   1,
#   30,
#   31,
#   33,
#   22,
#   47,
#   5,
#   28,
#   55,
#   40,
#   52,
#   42,
#   25,
#   38],
#  13: [9,
#   54,
#   5,
#   4,
#   57,
#   37,
#   31,
#   6,
#   3,
#   36,
#   7,
#   58,
#   40,
#   35,
#   24,
#   32,
#   16,
#   10,
#   14,
#   45,
#   17,
#   55,
#   22,
#   42,
#   38,
#   13,
#   41,
#   49,
#   47,
#   39,
#   46,
#   21,
#   2,
#   29,
#   27,
#   44,
#   34,
#   53,
#   33,
#   20,
#   59,
#   23,
#   50,
#   15,
#   0,
#   25,
#   52,
#   18,
#   26,
#   43,
#   12,
#   1,
#   28,
#   48,
#   8,
#   51,
#   30,
#   11,
#   19,
#   56],
#  14: [14,
#   10,
#   56,
#   1,
#   29,
#   25,
#   37,
#   7,
#   23,
#   19,
#   44,
#   34,
#   30,
#   54,
#   48,
#   18,
#   26,
#   6,
#   24,
#   35,
#   8,
#   15,
#   32,
#   52,
#   43,
#   39,
#   57,
#   13,
#   0,
#   53,
#   33,
#   47,
#   42,
#   2,
#   27,
#   59,
#   45,
#   46,
#   12,
#   50,
#   38,
#   5,
#   31,
#   4,
#   28,
#   49,
#   16,
#   51,
#   20,
#   40,
#   21,
#   22,
#   17,
#   41,
#   36,
#   58,
#   3,
#   55,
#   11,
#   9],
#  15: [19,
#   2,
#   7,
#   25,
#   49,
#   29,
#   12,
#   59,
#   20,
#   42,
#   5,
#   41,
#   3,
#   34,
#   44,
#   48,
#   38,
#   23,
#   35,
#   24,
#   13,
#   11,
#   53,
#   47,
#   9,
#   55,
#   17,
#   54,
#   51,
#   22,
#   21,
#   31,
#   1,
#   8,
#   33,
#   6,
#   56,
#   43,
#   27,
#   39,
#   50,
#   36,
#   4,
#   14,
#   16,
#   28,
#   26,
#   18,
#   10,
#   40,
#   37,
#   57,
#   45,
#   30,
#   32,
#   58,
#   15,
#   52,
#   46,
#   0],
#  16: [47,
#   19,
#   56,
#   40,
#   59,
#   7,
#   54,
#   58,
#   16,
#   24,
#   10,
#   8,
#   4,
#   21,
#   49,
#   34,
#   33,
#   44,
#   23,
#   12,
#   22,
#   20,
#   29,
#   52,
#   3,
#   18,
#   2,
#   37,
#   27,
#   17,
#   57,
#   26,
#   9,
#   55,
#   50,
#   51,
#   11,
#   41,
#   43,
#   14,
#   30,
#   53,
#   42,
#   0,
#   1,
#   38,
#   45,
#   48,
#   13,
#   46,
#   31,
#   6,
#   5,
#   28,
#   36,
#   25,
#   39,
#   32,
#   35,
#   15],
#  17: [16,
#   21,
#   56,
#   58,
#   3,
#   27,
#   59,
#   40,
#   46,
#   33,
#   5,
#   55,
#   38,
#   6,
#   30,
#   29,
#   24,
#   53,
#   34,
#   17,
#   37,
#   1,
#   8,
#   4,
#   52,
#   57,
#   31,
#   41,
#   10,
#   22,
#   12,
#   25,
#   45,
#   42,
#   19,
#   0,
#   13,
#   26,
#   23,
#   54,
#   2,
#   7,
#   44,
#   47,
#   20,
#   43,
#   36,
#   35,
#   51,
#   11,
#   50,
#   28,
#   18,
#   14,
#   39,
#   48,
#   15,
#   9,
#   32,
#   49],
#  18: [15,
#   41,
#   46,
#   3,
#   13,
#   24,
#   28,
#   34,
#   30,
#   4,
#   31,
#   42,
#   20,
#   33,
#   37,
#   48,
#   10,
#   5,
#   59,
#   0,
#   47,
#   58,
#   38,
#   18,
#   45,
#   49,
#   51,
#   52,
#   53,
#   55,
#   12,
#   16,
#   6,
#   14,
#   57,
#   36,
#   22,
#   40,
#   43,
#   1,
#   26,
#   19,
#   25,
#   27,
#   2,
#   8,
#   56,
#   23,
#   17,
#   32,
#   50,
#   11,
#   54,
#   39,
#   35,
#   9,
#   7,
#   29,
#   21,
#   44],
#  19: [32,
#   15,
#   19,
#   23,
#   44,
#   14,
#   5,
#   47,
#   8,
#   40,
#   10,
#   11,
#   49,
#   7,
#   25,
#   2,
#   53,
#   12,
#   42,
#   58,
#   59,
#   26,
#   9,
#   50,
#   56,
#   20,
#   51,
#   28,
#   55,
#   36,
#   16,
#   45,
#   4,
#   0,
#   13,
#   46,
#   1,
#   24,
#   17,
#   39,
#   38,
#   22,
#   35,
#   37,
#   29,
#   18,
#   43,
#   48,
#   52,
#   41,
#   34,
#   30,
#   6,
#   54,
#   57,
#   33,
#   27,
#   31,
#   3,
#   21],
#  20: [12,
#   44,
#   50,
#   39,
#   11,
#   29,
#   3,
#   32,
#   53,
#   46,
#   38,
#   51,
#   45,
#   9,
#   56,
#   4,
#   28,
#   21,
#   1,
#   47,
#   41,
#   6,
#   27,
#   13,
#   54,
#   7,
#   43,
#   22,
#   14,
#   31,
#   16,
#   40,
#   8,
#   30,
#   48,
#   15,
#   20,
#   52,
#   0,
#   57,
#   26,
#   59,
#   35,
#   10,
#   24,
#   17,
#   23,
#   55,
#   34,
#   19,
#   18,
#   2,
#   36,
#   37,
#   42,
#   25,
#   33,
#   49,
#   58,
#   5],
#  21: [46,
#   4,
#   11,
#   12,
#   42,
#   44,
#   32,
#   55,
#   13,
#   5,
#   30,
#   16,
#   45,
#   23,
#   31,
#   19,
#   7,
#   53,
#   17,
#   3,
#   40,
#   34,
#   57,
#   33,
#   49,
#   14,
#   29,
#   48,
#   22,
#   15,
#   59,
#   54,
#   28,
#   38,
#   25,
#   0,
#   21,
#   8,
#   50,
#   58,
#   36,
#   39,
#   27,
#   18,
#   2,
#   43,
#   26,
#   52,
#   1,
#   24,
#   41,
#   37,
#   10,
#   20,
#   51,
#   6,
#   35,
#   56,
#   9,
#   47],
#  22: [30,
#   57,
#   22,
#   47,
#   21,
#   27,
#   56,
#   9,
#   54,
#   2,
#   46,
#   14,
#   18,
#   43,
#   55,
#   35,
#   1,
#   37,
#   0,
#   33,
#   32,
#   39,
#   10,
#   12,
#   44,
#   23,
#   13,
#   15,
#   59,
#   52,
#   17,
#   38,
#   36,
#   28,
#   3,
#   50,
#   48,
#   42,
#   24,
#   26,
#   31,
#   58,
#   49,
#   45,
#   7,
#   20,
#   11,
#   4,
#   19,
#   40,
#   25,
#   6,
#   34,
#   29,
#   41,
#   5,
#   51,
#   8,
#   53,
#   16],
#  23: [38,
#   9,
#   26,
#   52,
#   3,
#   41,
#   42,
#   14,
#   8,
#   7,
#   54,
#   22,
#   16,
#   6,
#   46,
#   48,
#   34,
#   35,
#   59,
#   13,
#   37,
#   2,
#   23,
#   43,
#   19,
#   24,
#   39,
#   15,
#   18,
#   12,
#   50,
#   53,
#   1,
#   11,
#   40,
#   0,
#   17,
#   58,
#   5,
#   21,
#   47,
#   51,
#   4,
#   29,
#   36,
#   28,
#   49,
#   31,
#   30,
#   45,
#   10,
#   27,
#   25,
#   57,
#   32,
#   33,
#   55,
#   56,
#   20,
#   44],
#  24: [12,
#   21,
#   38,
#   18,
#   13,
#   10,
#   45,
#   32,
#   50,
#   0,
#   25,
#   6,
#   16,
#   9,
#   24,
#   15,
#   54,
#   58,
#   23,
#   19,
#   28,
#   26,
#   27,
#   3,
#   49,
#   7,
#   17,
#   56,
#   48,
#   29,
#   39,
#   35,
#   46,
#   53,
#   59,
#   11,
#   51,
#   2,
#   43,
#   34,
#   30,
#   31,
#   40,
#   5,
#   57,
#   8,
#   1,
#   33,
#   52,
#   14,
#   37,
#   47,
#   36,
#   4,
#   22,
#   44,
#   55,
#   20,
#   41,
#   42],
#  25: [17,
#   30,
#   12,
#   28,
#   4,
#   51,
#   38,
#   19,
#   5,
#   53,
#   49,
#   26,
#   7,
#   41,
#   20,
#   44,
#   55,
#   11,
#   16,
#   48,
#   40,
#   2,
#   14,
#   15,
#   13,
#   21,
#   22,
#   10,
#   31,
#   50,
#   1,
#   37,
#   34,
#   57,
#   45,
#   47,
#   52,
#   42,
#   43,
#   54,
#   59,
#   33,
#   39,
#   25,
#   9,
#   6,
#   3,
#   23,
#   58,
#   36,
#   46,
#   18,
#   27,
#   35,
#   32,
#   24,
#   0,
#   8,
#   56,
#   29],
#  26: [10,
#   13,
#   26,
#   34,
#   27,
#   6,
#   22,
#   16,
#   15,
#   19,
#   52,
#   56,
#   40,
#   4,
#   23,
#   18,
#   39,
#   46,
#   35,
#   5,
#   20,
#   24,
#   41,
#   17,
#   32,
#   47,
#   31,
#   43,
#   53,
#   30,
#   57,
#   59,
#   25,
#   12,
#   1,
#   51,
#   37,
#   2,
#   29,
#   54,
#   9,
#   58,
#   42,
#   8,
#   55,
#   36,
#   33,
#   7,
#   11,
#   38,
#   45,
#   0,
#   3,
#   14,
#   50,
#   44,
#   49,
#   48,
#   28,
#   21],
#  27: [17,
#   15,
#   4,
#   45,
#   43,
#   23,
#   54,
#   19,
#   44,
#   1,
#   51,
#   56,
#   59,
#   0,
#   35,
#   30,
#   5,
#   37,
#   55,
#   41,
#   52,
#   48,
#   14,
#   40,
#   50,
#   36,
#   28,
#   12,
#   47,
#   11,
#   26,
#   6,
#   32,
#   39,
#   8,
#   46,
#   18,
#   22,
#   21,
#   53,
#   10,
#   9,
#   25,
#   13,
#   3,
#   7,
#   31,
#   38,
#   16,
#   27,
#   57,
#   20,
#   29,
#   24,
#   49,
#   58,
#   34,
#   42,
#   33,
#   2],
#  28: [5,
#   38,
#   34,
#   6,
#   17,
#   21,
#   39,
#   12,
#   32,
#   4,
#   15,
#   18,
#   48,
#   41,
#   25,
#   47,
#   44,
#   1,
#   14,
#   24,
#   2,
#   55,
#   16,
#   8,
#   7,
#   54,
#   23,
#   52,
#   37,
#   20,
#   40,
#   36,
#   57,
#   26,
#   13,
#   30,
#   45,
#   56,
#   58,
#   35,
#   59,
#   19,
#   46,
#   33,
#   50,
#   49,
#   29,
#   9,
#   42,
#   11,
#   28,
#   22,
#   43,
#   53,
#   51,
#   3,
#   0,
#   31,
#   27,
#   10],
#  29: [38,
#   9,
#   31,
#   35,
#   2,
#   49,
#   40,
#   41,
#   36,
#   21,
#   10,
#   28,
#   50,
#   48,
#   29,
#   32,
#   39,
#   23,
#   19,
#   17,
#   4,
#   1,
#   20,
#   13,
#   37,
#   33,
#   5,
#   42,
#   57,
#   58,
#   26,
#   51,
#   47,
#   59,
#   6,
#   16,
#   30,
#   27,
#   55,
#   46,
#   3,
#   44,
#   53,
#   56,
#   0,
#   52,
#   54,
#   14,
#   15,
#   8,
#   18,
#   7,
#   45,
#   25,
#   24,
#   22,
#   11,
#   43,
#   12,
#   34]}
